# %%
# uniformquantization
x = [6,8]
y = [18.7,37.0]
# group quant
x = [6,8]
y = [35.0,37.1]
# outlier quantization 0.02
x = [4,6]
y = [24.5,36.7]
# outlier quantization 0.01
x = [4,6]
y = [22.1,36.2]
# outlier quantization 0.02 with 0.1 rank ap
x = [4,6]
y = [37.0,37.1]
# outlier quantization 0.02 with 0.1 rank ap
x = [4,6]
y = [37.0,37.1]
# outlier quantization 0.02 with 0.05 rank ap
x = [4,6]
y = [36.0,37.1]

# %%
import matplotlib.pyplot as plt

# 数据及线条标签
data = [
    ([6,8,12], [11.3,25.4,35.7], 'H2O'),
    ([4,6,8], [2.1,18.7,37.0], 'Uniform Quantization'),
    ([4,6,8], [7.2,35.0,37.1], 'Group Quantization'),
    ([4,6,8], [24.7,36.7,37.1], 'Outlier Quantization 0.10'),
    ([4,6,8], [24.5,36.7,37.1], 'Outlier Quantization 0.02'),
    ([4,6,8], [22.1,36.2,37.1], 'Outlier Quantization 0.01'),
    ([4,6,8], [37.0,37.1,37.1], 'Outlier Quantization 0.02 with 0.1 rank ap'),
    ([4,6,8], [37.0,37.1,37.1], 'Outlier Quantization 0.02 with 0.1 rank ap'),
    ([4,6,8], [36.0,37.1,37.1], 'Outlier Quantization 0.02 with 0.05 rank ap')
]

# 绘制折线图
for x, y, label in data:
    plt.plot(x, y, label=label)

# 设置图标题和轴标签
plt.title('GSM8k Finetuned on Llama2-7b')
plt.xlabel('X')
plt.ylabel('Y')

# 显示图例
plt.legend()

# 显示图形
plt.show()
